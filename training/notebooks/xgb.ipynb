# %%
import numpy as np
import matplotlib as plt
import pandas as pd
# Out:
# The kernel failed to start as the Python Environment 'Grip (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
